# %%
import pandas as pd

df=pd.read_csv("spotify_tracks.csv")
df.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'artist_name', 'year', 'popularity',
#        'artwork_url', 'album_name', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'track_url', 'language'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# track_id            0
# track_name          0
# artist_name         0
# year                0
# popularity          0
# artwork_url         0
# album_name          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# track_url           0
# language            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 78

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 62312    False
# 62313    False
# 62314    False
# 62315    False
# 62316    False
# Length: 62317, dtype: bool

# %%
df.drop_duplicates()
# Out:
#                      track_id                                  track_name  \
# 0      2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1      4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2      59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3      5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4      1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
# ...                       ...                                         ...
# 62312  3eHDwMQYPEziy2DWRBNoLv                        Sani - G.O.A.T Remix
# 62313  5hHtCqkNv5eo99OrEFFcgS                            Life of Bachelor
# 62314  08foF9YHgKmIgOy3xMWRZy                                     Yo Baby
# 62315  2wLFbVlQGKJSd9lwzwL47F                           Fast Fast Vadiley
# 62316  5OYxwYeFfumMTAoAdVeet3             Moonu Moonu Moonu (From "3:33")
#
#                                              artist_name  year  popularity  \
# ...

# %%
# Identify duplicated rows
duplicated_rows = df[df.duplicated()]

# Print the columns of duplicated rows
print(duplicated_rows)
# Out:
#                     track_id                                   track_name  \
# 2495  50RcuWjfUcoJfWMNegXF0b             Ee Raathale (From "Radhe Shyam")
# 2496  5zDRx2IlpoiNHBpmG4btVN  Per Vachaalum Vaikkaama (From "Dikkiloona")
# 2497  3huCRjAX12zNPxtX9JqX2X           Naanga Vera Maari (From "Valimai")
# 2498  21r0QnhYxsxYUsoov5o0IF                      Per Vachaalum Vaikkaama
# 2499  42LMjL86cep0L8QA1q0doE                               Voice Of Unity
# ...                      ...                                          ...
# 2568  2sYIrPDAeu3i9vlVrofwvh         Harla Farla (From "Chakra (Telugu)")
# 2569  0DqKN7Wg0lsQaf6MuaREpX                         Munnala Ninna Pothum
# 2570  7jSXMBdFfshfffYQmWWbHz                 Maari Gethu (From "Maari 2")
# 2571  6DVTHHdDFEnL9UcDaLSCvg                              Suttute Suttute
# 2572  08elXSPBnP9uFYkjpObT5T     Yaaro Ucchikilai Meley (From "Taramani")
#
#                                             artist_name  year  popularity  \
# ...

# %%
df.drop('track_url', axis=1, inplace=True)

# %%
df.drop('time_signature', axis=1, inplace=True)

# %%
df.drop('track_id', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                    track_name  \
# 0                  Leo Das Entry (From "Leo")
# 1                                AAO KILLELLE
# 2      Mayakiriye Sirikiriye - Orchestral EDM
# 3    Scene Ah Scene Ah - Experimental EDM Mix
# 4  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# 1  https://i.scdn.co/image/ab67616d0000b273be1b03...
# 2  https://i.scdn.co/image/ab67616d0000b27334a1dd...
# ...

# %%
df.drop('artwork_url', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                    track_name  \
# 0                  Leo Das Entry (From "Leo")
# 1                                AAO KILLELLE
# 2      Mayakiriye Sirikiriye - Orchestral EDM
# 3    Scene Ah Scene Ah - Experimental EDM Mix
# 4  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                    album_name  acousticness  danceability  \
# 0                  Leo Das Entry (From "Leo")        0.0241         0.753
# 1                                AAO KILLELLE        0.0851         0.780
# ...

# %% [markdown]
# # POPULARITY VS YEAR

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='year', y='popularity')
plt.title('Popularity of Tracks Over the Years')
plt.xlabel('Year')
plt.ylabel('Popularity')
plt.show()

# %% [markdown]
# # DANCEABILITY VS TEMPO

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='tempo', y='danceability')
plt.title('Danceability vs. Tempo')
plt.xlabel('Tempo (BPM)')
plt.ylabel('Danceability')
plt.show()

# %% [markdown]
# # LOUDNESS VS ENERGY

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='loudness', y='energy')
plt.title('Loudness vs. Energy')
plt.xlabel('Loudness')
plt.ylabel('Energy')
plt.show()

# %% [markdown]
# ### 1. Popularity of Tracks Over the Years
# This line plot shows how the popularity of tracks has changed over the years. It helps in understanding trends in music popularity over time.
#
# **Analysis**:
# - The graph indicates fluctuations in the popularity of tracks over different years.
# - Peaks in popularity might correspond to the release of hit songs or albums.
# - Understanding these trends can help in predicting future popular tracks and identifying key factors that contribute to a track's success.
#
# ### 2. Danceability vs. Tempo
# This scatter plot illustrates the relationship between danceability and tempo of the tracks. It can help identify how tempo influences the danceability of a song.
#
# **Analysis**:
# - There is a noticeable correlation between tempo and danceability.
# - Tracks with higher tempos tend to have higher danceability scores, making them more suitable for dancing.
# - This information can be useful for music producers and DJs when creating or selecting tracks for dance events.
#
# ### 3. Loudness vs. Energy
# This scatter plot shows the relationship between loudness and energy of the tracks. It helps in understanding how these two attributes correlate with each other.
#
# **Analysis**:
# - The graph shows a positive correlation between loudness and energy.
# - Tracks with higher loudness levels tend to have higher energy, making them more dynamic and engaging.
# - This insight can be valuable for audio engineers and music producers aiming to create high-energy tracks.
